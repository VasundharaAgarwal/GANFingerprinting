# %%
from google.colab import drive
import os
import sys
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
sys.path.append('/content/gdrive/My Drive/')
import fp_utilities as fp_util

# %%
marra_preds = fp_util.get_predictions('Marra', attack_mode="adv1")

# %%
fp_util.plot_confusion_matrix(marra_preds)

# %%
yu_preds = fp_util.get_predictions('Yu', attack_mode='adv1')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
fp_util.plot_confusion_matrix(yu_preds)

# %%
fp_util.plot_corr_histograms('Yu', attack_mode='adv1')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
